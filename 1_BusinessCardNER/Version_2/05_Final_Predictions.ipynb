# %%
import cv2
import matplotlib.pyplot as plt
import predictions as pred
# Out:
# /Volumes/STARLAI/Developments/PyCharmProject/Document Scanner/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def show_img(img):
    fig = plt.gcf()
    fig.set_size_inches(16, 8)
    plt.axis(False)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
img = cv2.imread('data/242.jpeg')
show_img(img)

# %%
img_results, entities = pred.get_predictions(img)
show_img(img_results)

# %%
entities
# Out:
# {'NAME': ['Dr T S Reddy'],
#  'ORG': ['Lea Associates South Asia Pvt Ltd'],
#  'DES': ['Senior Consultant'],
#  'PHONE': ['91', '66747135', '9182230'],
#  'EMAIL': ['122', 'tsr@lasaindia.com', 'limmappagari@ymait.com'],
#  'WEB': ['www.lasaindia.com']}

# %%
img = cv2.imread('data/54.jpg')
show_img(img)

# %%
img_results, entities = pred.get_predictions(img)
show_img(img_results)

# %%
entities
# Out:
# {'NAME': ['Joseph C Wu', 'Md'],
#  'ORG': [' Medicine Cardiovascular Institute'],
#  'DES': ['Director'],
#  'PHONE': ['650736'],
#  'EMAIL': ['joewu@stanford.edu'],
#  'WEB': ['http//wulab.stanford.edu', 'http//evistanford.edu']}
